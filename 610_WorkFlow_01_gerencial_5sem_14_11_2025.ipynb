# %% [markdown]
# <a href="https://colab.research.google.com/github/aleanaliaaustral-web/labo2025v/blob/main/610_WorkFlow_01_gerencial_5sem_14_11_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Nov 14 01:07:01 PM 2025"

# %%
rm(list = ls()) # Borrar todos los objetos
gc(verbose= FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  807067 43.2  1454477    77.7  1454477  77.7
# Vcells 1531075 11.7 28994969   221.3 33992409 259.4

# %% [markdown]
# cargo la libreria

# %%
# Instalar todas las dependencias necesarias para mlrMBO
install.packages("ParamHelpers")
install.packages("smoof")
install.packages("mlr")
install.packages("mlrMBO")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘BBmisc’, ‘checkmate’, ‘fastmatch’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘RcppArmadillo’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘parallelMap’, ‘XML’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘lhs’

# %%
# Instalar lightgbm desde CRAN
install.packages("lightgbm", repos = "https://cran.r-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Instalar DiceKriging y otras dependencias necesarias
install.packages("DiceKriging")
install.packages("rgenoud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
equire("data.table")
require("lightgbm")
require("mlrMBO")
require("mlrMBO")
require("ParamHelpers")  # <- Agregá esta línea

library(data.table)
library(lightgbm)
library(ParamHelpers)
library(mlrMBO)

# %%
# NO OLVIDAR REEMPLAZAR SEMILLA PRIMIGENIA!

PARAM <- list()

# por ahora NO modifique este script
PARAM$experimento <- "WF6100"
PARAM$semilla_primigenia <- 206262 # reemplazar por SU semilla primigenia

# establecer el Working Directory por defecto
setwd("/content/buckets/b1/exp/")

# %%
# creo la carpeta para este experimento
dir.create(paste0(PARAM$experimento, "/"), showWarnings= FALSE)
setwd(paste0(PARAM$experimento, "/")) # Establezco el Working Directory DEL EXPERIMENTO

setwd(paste0("./"))

# %%
# CAMBIAR NOMBRE DEL EXPERIMENTO POR CADA CORRIDA

PARAM$experimento <- "WF6100" # You can change "WF6100" to your desired experiment name

# %%
# Instalar R.utils si no está disponible
if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

# %% [markdown]
# #### Data Loading

# %%
dataset <- fread("/content/datasets/gerencial_competencia_2025.csv.gz")

# %% [markdown]
# #### Data Drifting

# %%
# En esta semilla, NO hay data drifting
# los alumnos que tengan su dataset SIN data drifting, deben cambiar este parametro a FALSE

PARAM$drifting$hay_drifting <- TRUE

if( PARAM$drifting$hay_drifting ) {
  dataset[foto_mes == 202107, clase_ternaria := ifelse(clase_ternaria == "CONTINUA", "BAJA+2", clase_ternaria)]
}

# %% [markdown]
# #### Training Strategy

# %% [markdown]
# Establezco los periodos que voy a usar para train y test

# %%
# la training strategy del ejemplo del notebook
# no es la mejor, deben reemplazarlo por la que Uds encontraron,
# donde SEGURO hicieron un trabajo EXCELENTE con el script  z211_creacion_TS.r
# ¿ verdad que ese fue el caso ?

PARAM$trainingstrategy$training <- c(202103, 202104, 202105)
PARAM$trainingstrategy$validation <- c(202107)
PARAM$trainingstrategy$testing <- c(202109)
PARAM$trainingstrategy$final_train <- c(202103, 202104, 202105, 202107)
PARAM$trainingstrategy$future <- c(202109)

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# Voy a crear 60 lagueados estadisticos

# %%
cols_lagueables <- copy(setdiff(
  colnames(dataset),
  c("numero_de_cliente", "foto_mes", "clase_ternaria")
))

# ordeno de esta forma por el concepto de Tempus Fugit
setorder(dataset, numero_de_cliente, foto_mes)

# %%
PARAM$lag$meses <- 2 # 2 meses de lag
PARAM$lag$deltas <- TRUE # con tendencia
PARAM$lag$delta_pct <- FALSE # sin tendencia porcentual

# %%
# creo los campos lags de orden 1 y 2
# como hay que ordenar por { numero_de_cliente, foto_mes }
# debo utilizar Rcpp

for (vcol in cols_lagueables) {
  for (im in 1:PARAM$lag$meses) {
    dataset[, paste0(vcol, "_lag", im) :=
      shift(get(vcol), n = im, type = "lag"),
    by = numero_de_cliente]
  }
}

if( PARAM$lag$deltas ){
  # diferencias con lags en forma NO porcentual
  for (vcol in cols_lagueables) {
    for (im in 1:PARAM$lag$meses) {
      dataset[, paste0(vcol, "_delta", im) :=
        get(vcol) - get(paste0(vcol, "_lag", im))]
    }
  }
}

if( PARAM$lag$delta_pct ){
  # diferencias con lags en forma porcentual
  for (vcol in cols_lagueables) {
    for (im in 1:PARAM$lag$meses) {
      dataset[, paste0(vcol, "_delta", im, "_pct") :=
        get(paste0(vcol, "_delta", im)) /  (get(paste0(vcol, "_lag", im)) + 0.0001)]
    }
  }
}

# %%
# defino los nombres de los campos
campos_buenos <- setdiff(colnames(dataset), c("numero_de_cliente", "foto_mes", "clase_ternaria"))

# %% [markdown]
# #### Bayesian Optimization - Hiperparametros
#
# **AQUÍ ESTÁ LA CORRECCIÓN DEL BUG**

# %% [markdown]
# Aqui se deben agregar los hiperparametros que quieren optimizar

# %%
# Aqui se cargan los hiperparametros

PARAM$bo_lgb <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.01, upper = 0.2),
  makeNumericParam("feature_fraction", lower = 0.3, upper = 1.0),
  makeIntegerParam("min_data_in_leaf", lower = 0L, upper = 4000L),
  makeIntegerParam("num_leaves", lower = 8L, upper = 1024L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 10.0),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 10.0)
)

# Aqui la cantidad de iteraciones de la Bayesian Optimization
PARAM$bo_iteraciones <- 50

# Ahora defino el controlador para pasar por las 5 semillas
# Uso 1 semilla original + 4 semillas adicionales generadas aleatoriamente

PARAM$semillas <- c(PARAM$semilla_primigenia)
set.seed(PARAM$semilla_primigenia)
for(i in 1:4) {
  PARAM$semillas <- c(PARAM$semillas, sample.int(1000000, 1))
}

# %%
# AQUÍ ESTÁ LA CORRECCIÓN PRINCIPAL:
# num_iterations y early_stopping_rounds NO van como extras, van en el parámetro fijos

PARAM$out <- list()
PARAM$out$lgbm <- list()
PARAM$out$lgbm$mejor_ganancia <- -Inf

# funcion que optimiza con 5 semillas distintas y toma el promedio
# Recibe hiperparametros de LGBM
fganancia_lgbm_meseta <- function(x) {
  # inicializo en cero los vectores para acumular ganancias
  ganancias <- numeric(length(PARAM$semillas))

  # para cada semilla
  for(idx_semilla in 1:length(PARAM$semillas)) {
    semilla_actual <- PARAM$semillas[idx_semilla]

    # defino los parametros COMPLETOS
    # CORRECCIÓN: num_iterations y early_stopping_rounds van en param_train
    param_train <- list(
      objective = "binary",
      metric = "custom",
      first_metric_only = TRUE,
      boost_from_average = TRUE,
      feature_pre_filter = FALSE,
      num_iterations = 9999,  # MOVIDO AQUÍ
      early_stopping_rounds = 200,  # MOVIDO AQUÍ
      verbosity = -100,
      seed = semilla_actual,
      max_depth = -1,
      min_gain_to_split = 0.0,
      min_sum_hessian_in_leaf = 0.001,
      lambda_l1 = x$lambda_l1,
      lambda_l2 = x$lambda_l2,
      learning_rate = x$learning_rate,
      feature_fraction = x$feature_fraction,
      min_data_in_leaf = x$min_data_in_leaf,
      num_leaves = x$num_leaves
    )

    # genero el modelo con esta semilla
    modelo <- lgb.train(
      data = dtrain,
      valids = list(valid = dvalidate),
      eval = lgb_gan_eval,
      param = param_train  # Ya incluye todo lo necesario
    )

    # capturo la ganancia
    ganancias[idx_semilla] <- unlist(modelo$record_evals$valid$ganancia$eval)[[modelo$best_iter]]
  }

  # calculo ganancia promedio
  ganancia_promedio <- mean(ganancias)
  ganancia_promedio_normalizada <- ganancia_promedio * 0.3

  # si esta ganancia es mejor que la mejor hasta ahora, la guardo
  if (ganancia_promedio_normalizada > PARAM$out$lgbm$mejor_ganancia) {
    PARAM$out$lgbm$mejor_ganancia <<- ganancia_promedio_normalizada
    PARAM$out$lgbm$mejores_hiperparametros <<- as.list(x)
    PARAM$out$lgbm$mejor_iteracion <<- modelo$best_iter
  }

  return(ganancia_promedio_normalizada)
}

# %%
# creo los datasets de training y validation
dtrain <- lgb.Dataset(
  data = data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$training, campos_buenos, with = FALSE]),
  label = dataset[foto_mes %in% PARAM$trainingstrategy$training, ifelse(clase_ternaria == "BAJA+2", 1L, 0L)],
  free_raw_data = FALSE
)

dvalidate <- lgb.Dataset(
  data = data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validation, campos_buenos, with = FALSE]),
  label = dataset[foto_mes %in% PARAM$trainingstrategy$validation, ifelse(clase_ternaria == "BAJA+2", 1L, 0L)],
  free_raw_data = FALSE
)

# %%
# Defino la metrica customizada ganancia usando la clase binaria BAJA+2
lgb_gan_eval <- function(y_pred, dtrain) {
  # Obtener labels usando el método correcto para lgb.Dataset
  labels <- dtrain$get_field("label")

  # vector de ganancias
  gan <- ifelse(labels == 1 & y_pred >= 0.025, 273000,
    ifelse(labels == 0 & y_pred >= 0.025, -7000, 0)
  )

  # esta es la ganancia
  ganancia <- sum(gan)

  return(list(
    name = "ganancia",
    value = ganancia,
    higher_better = TRUE
  ))
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana, los hiperparametros que se van a optimizar
obj.fun <- makeSingleObjectiveFunction(
  name = "lgbm_ganancia",
  fn = fganancia_lgbm_meseta,
  par.set = PARAM$bo_lgb,
  has.simple.signature = FALSE,
  minimize = FALSE  # <-- cambiar 'minimization' por 'minimize'
)

ctrl <- makeMBOControl()
ctrl <- setMBOControlTermination(ctrl, iters = PARAM$bo_iteraciones)
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# inicio la optimizacion bayesiana
if (!file.exists("bayesiana.RDATA")) {
  run <- mbo(obj.fun, control = ctrl)

  # salvo a disco el resultado
  save(run, file = "bayesiana.RDATA")
} else {
  # cargo el resultado
  load(file = "bayesiana.RDATA")
}
# Out:
# Computing y column(s) for design. Not provided.
#
# [mbo] 0: learning_rate=0.133; feature_fraction=0.546; min_data_in_leaf=1429; num_leaves=792; lambda_l1=8.52; lambda_l2=8.48 : y = 4.76e+07 : 52.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.107; feature_fraction=0.686; min_data_in_leaf=2863; num_leaves=439; lambda_l1=0.446; lambda_l2=5.69 : y = 4.8e+07 : 40.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.156; feature_fraction=0.725; min_data_in_leaf=2703; num_leaves=754; lambda_l1=5.89; lambda_l2=7.48 : y = 4.75e+07 : 30.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.184; feature_fraction=0.65; min_data_in_leaf=845; num_leaves=23; lambda_l1=3.99; lambda_l2=4.76 : y = 4.66e+07 : 28.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0517; feature_fraction=0.78; min_data_in_leaf=2244; num_leaves=175; lambda_l1=3.47; lambda_l2=6.19 : y = 4.77e+07 : 54.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0966; feature_fraction=0.646; min_data_in_leaf=3579; num_leaves=522; lambda_l1=5.06; lambda_l2=1.32 : y = 4.79e+07 : 38.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.166; feature_fraction=0.494; min_data_in_leaf=733; num_leaves=324; lambda_l1=9.65; lambda_l2=4.15 : y = 4.6e+07 : 32.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.144; feature_fraction=0.473; min_data_in_leaf=1774; num_leaves=627; lambda_l1=2.99; lambda_l2=9.09 : y = 4.72e+07 : 54.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0384; feature_fraction=0.92; min_data_in_leaf=1006; num_leaves=711; lambda_l1=4.9; lambda_l2=2.07 : y = 4.67e+07 : 64.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.121; feature_fraction=0.347; min_data_in_leaf=3307; num_leaves=896; lambda_l1=2.25; lambda_l2=3.58 : y = 4.88e+07 : 44.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.195; feature_fraction=0.85; min_data_in_leaf=2367; num_leaves=477; lambda_l1=8.94; lambda_l2=0.754 : y = 4.68e+07 : 23.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.118; feature_fraction=0.602; min_data_in_leaf=2607; num_leaves=108; lambda_l1=8.1; lambda_l2=7.71 : y = 4.67e+07 : 33.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0292; feature_fraction=0.512; min_data_in_leaf=1586; num_leaves=577; lambda_l1=6.94; lambda_l2=5.2 : y = 4.72e+07 : 94.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0494; feature_fraction=0.388; min_data_in_leaf=70; num_leaves=367; lambda_l1=1.24; lambda_l2=9.37 : y = 3.94e+07 : 80.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.103; feature_fraction=0.577; min_data_in_leaf=1290; num_leaves=1009; lambda_l1=5.55; lambda_l2=0.947 : y = 4.58e+07 : 54.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0727; feature_fraction=0.75; min_data_in_leaf=379; num_leaves=278; lambda_l1=0.294; lambda_l2=3.17 : y = 3.95e+07 : 64.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0787; feature_fraction=0.804; min_data_in_leaf=1866; num_leaves=211; lambda_l1=9.22; lambda_l2=0.273 : y = 4.79e+07 : 28.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.191; feature_fraction=0.854; min_data_in_leaf=174; num_leaves=410; lambda_l1=7.67; lambda_l2=6.8 : y = 4.36e+07 : 24.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.172; feature_fraction=0.912; min_data_in_leaf=3118; num_leaves=901; lambda_l1=2.67; lambda_l2=6.43 : y = 4.83e+07 : 40.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0131; feature_fraction=0.429; min_data_in_leaf=3473; num_leaves=826; lambda_l1=2.02; lambda_l2=2.42 : y = 4.94e+07 : 131.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0204; feature_fraction=0.306; min_data_in_leaf=3802; num_leaves=663; lambda_l1=7.18; lambda_l2=9.98 : y = 4.74e+07 : 132.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0841; feature_fraction=1; min_data_in_leaf=3852; num_leaves=73; lambda_l1=1.53; lambda_l2=4.53 : y = 4.86e+07 : 49.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0594; feature_fraction=0.965; min_data_in_leaf=602; num_leaves=942; lambda_l1=6.35; lambda_l2=8.22 : y = 4.8e+07 : 55.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.147; feature_fraction=0.374; min_data_in_leaf=2040; num_leaves=253; lambda_l1=4.31; lambda_l2=2.62 : y = 4.69e+07 : 44.8 secs : initdesign
#
# [mbo] 1: learning_rate=0.0106; feature_fraction=0.776; min_data_in_leaf=3677; num_leaves=1019; lambda_l1=0.00267; lambda_l2=6.08 : y = 4.93e+07 : 134.5 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 2: learning_rate=0.0277; feature_fraction=0.999; min_data_in_leaf=1036; num_leaves=1006; lambda_l1=9.52; lambda_l2=9.98 : y = 4.79e+07 : 87.7 secs : infill_ei
#
# [mbo] 3: learning_rate=0.018; feature_fraction=0.319; min_data_in_leaf=4000; num_leaves=816; lambda_l1=0.0203; lambda_l2=2.73 : y = 4.98e+07 : 86.4 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 4: learning_rate=0.0203; feature_fraction=0.897; min_data_in_leaf=3998; num_leaves=764; lambda_l1=0.0161; lambda_l2=0.0971 : y = 4.88e+07 : 85.2 secs : infill_ei
#
# [mbo] 5: learning_rate=0.0114; feature_fraction=0.302; min_data_in_leaf=3716; num_leaves=402; lambda_l1=0.00321; lambda_l2=6.43 : y = 4.93e+07 : 138.8 secs : infill_ei
#
# [mbo] 6: learning_rate=0.0364; feature_fraction=0.418; min_data_in_leaf=3999; num_leaves=977; lambda_l1=1.59; lambda_l2=5.75 : y = 4.99e+07 : 74.4 secs : infill_ei
#
# [mbo] 7: learning_rate=0.198; feature_fraction=0.396; min_data_in_leaf=3995; num_leaves=899; lambda_l1=0.129; lambda_l2=5.88 : y = 5.23e+07 : 38.6 secs : infill_ei
#
# [mbo] 8: learning_rate=0.2; feature_fraction=0.481; min_data_in_leaf=4000; num_leaves=891; lambda_l1=0.0294; lambda_l2=9.69 : y = 5.04e+07 : 45.8 secs : infill_ei
#
# [mbo] 9: learning_rate=0.2; feature_fraction=0.389; min_data_in_leaf=3996; num_leaves=593; lambda_l1=0.00499; lambda_l2=3.4 : y = 5.31e+07 : 38.7 secs : infill_ei
#
# [mbo] 10: learning_rate=0.2; feature_fraction=0.364; min_data_in_leaf=4000; num_leaves=764; lambda_l1=0.0501; lambda_l2=1.04 : y = 5.25e+07 : 40.7 secs : infill_ei
#
# [mbo] 11: learning_rate=0.199; feature_fraction=0.37; min_data_in_leaf=4000; num_leaves=126; lambda_l1=0.0967; lambda_l2=3.49 : y = 5.29e+07 : 39.5 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 12: learning_rate=0.2; feature_fraction=0.366; min_data_in_leaf=4000; num_leaves=381; lambda_l1=0.677; lambda_l2=3.91 : y = 5.13e+07 : 39.7 secs : infill_ei
#
# [mbo] 13: learning_rate=0.0101; feature_fraction=0.809; min_data_in_leaf=3999; num_leaves=990; lambda_l1=4.06; lambda_l2=9.83 : y = 4.71e+07 : 152.8 secs : infill_ei
#
# [mbo] 14: learning_rate=0.194; feature_fraction=0.631; min_data_in_leaf=3996; num_leaves=808; lambda_l1=0.000978; lambda_l2=3.65 : y = 5.01e+07 : 34.4 secs : infill_ei
#
# [mbo] 15: learning_rate=0.199; feature_fraction=0.425; min_data_in_leaf=3991; num_leaves=8; lambda_l1=0.0166; lambda_l2=0.2 : y = 5.14e+07 : 40.9 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 16: learning_rate=0.2; feature_fraction=0.302; min_data_in_leaf=3987; num_leaves=80; lambda_l1=0.000557; lambda_l2=6.92 : y = 5.16e+07 : 33.9 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 17: learning_rate=0.196; feature_fraction=0.376; min_data_in_leaf=3991; num_leaves=663; lambda_l1=0.0129; lambda_l2=4.69 : y = 5.11e+07 : 41.3 secs : infill_ei
#
# [mbo] 18: learning_rate=0.0101; feature_fraction=0.981; min_data_in_leaf=3998; num_leaves=903; lambda_l1=9.7; lambda_l2=2.62 : y = 4.63e+07 : 172.4 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 19: learning_rate=0.188; feature_fraction=0.399; min_data_in_leaf=3966; num_leaves=222; lambda_l1=0.00169; lambda_l2=2.39 : y = 5.27e+07 : 41.5 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 20: learning_rate=0.2; feature_fraction=0.314; min_data_in_leaf=3998; num_leaves=940; lambda_l1=0.000783; lambda_l2=0.147 : y = 5.2e+07 : 38.6 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 21: learning_rate=0.19; feature_fraction=0.302; min_data_in_leaf=3838; num_leaves=1013; lambda_l1=0.00321; lambda_l2=2.82 : y = 5.04e+07 : 40.8 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 22: learning_rate=0.2; feature_fraction=0.349; min_data_in_leaf=3785; num_leaves=565; lambda_l1=0.0564; lambda_l2=0.193 : y = 5.2e+07 : 40.0 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 23: learning_rate=0.195; feature_fraction=0.308; min_data_in_leaf=4000; num_leaves=898; lambda_l1=0.0147; lambda_l2=7.26 : y = 5.13e+07 : 37.2 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 24: learning_rate=0.194; feature_fraction=0.476; min_data_in_leaf=3999; num_leaves=71; lambda_l1=0.00209; lambda_l2=6.67 : y = 5.04e+07 : 45.2 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 25: learning_rate=0.17; feature_fraction=0.301; min_data_in_leaf=3996; num_leaves=147; lambda_l1=1.61; lambda_l2=0.326 : y = 5.13e+07 : 38.5 secs : infill_ei
#
# [mbo] 26: learning_rate=0.178; feature_fraction=0.325; min_data_in_leaf=3059; num_leaves=90; lambda_l1=0.00663; lambda_l2=2.04 : y = 5.05e+07 : 40.6 secs : infill_ei
#
# [mbo] 27: learning_rate=0.116; feature_fraction=0.377; min_data_in_leaf=3992; num_leaves=720; lambda_l1=9.99; lambda_l2=0.00269 : y = 4.75e+07 : 47.6 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 28: learning_rate=0.199; feature_fraction=0.487; min_data_in_leaf=3907; num_leaves=207; lambda_l1=9.35; lambda_l2=3.94 : y = 4.84e+07 : 34.4 secs : infill_ei
#
# [mbo] 29: learning_rate=0.2; feature_fraction=0.435; min_data_in_leaf=3991; num_leaves=822; lambda_l1=9.18e-05; lambda_l2=3.19 : y = 5.17e+07 : 43.6 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 30: learning_rate=0.144; feature_fraction=0.3; min_data_in_leaf=3997; num_leaves=175; lambda_l1=0.0183; lambda_l2=3.71 : y = 4.99e+07 : 39.7 secs : infill_ei
#
# [mbo] 31: learning_rate=0.0101; feature_fraction=0.56; min_data_in_leaf=3998; num_leaves=11; lambda_l1=9.49; lambda_l2=0.018 : y = 4.74e+07 : 191.5 secs : infill_ei
#
# [mbo] 32: learning_rate=0.194; feature_fraction=0.304; min_data_in_leaf=3695; num_leaves=638; lambda_l1=1.12; lambda_l2=5.97 : y = 5.01e+07 : 38.4 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 33: learning_rate=0.01; feature_fraction=0.998; min_data_in_leaf=3952; num_leaves=534; lambda_l1=1.55; lambda_l2=6.14 : y = 4.83e+07 : 144.2 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 34: learning_rate=0.2; feature_fraction=0.402; min_data_in_leaf=4000; num_leaves=889; lambda_l1=2.95; lambda_l2=7.37 : y = 5.05e+07 : 44.6 secs : infill_ei
#
# [mbo] 35: learning_rate=0.2; feature_fraction=0.312; min_data_in_leaf=3999; num_leaves=583; lambda_l1=0.0253; lambda_l2=2.36 : y = 5.1e+07 : 32.8 secs : infill_ei
#
# [mbo] 36: learning_rate=0.186; feature_fraction=0.657; min_data_in_leaf=3914; num_leaves=1009; lambda_l1=4.24; lambda_l2=9.74 : y = 4.82e+07 : 32.4 secs : infill_ei
#
# [mbo] 37: learning_rate=0.192; feature_fraction=0.393; min_data_in_leaf=3967; num_leaves=736; lambda_l1=0.0299; lambda_l2=0.0208 : y = 5.24e+07 : 43.7 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 38: learning_rate=0.146; feature_fraction=1; min_data_in_leaf=2098; num_leaves=18; lambda_l1=0.0813; lambda_l2=9.78 : y = 4.52e+07 : 44.5 secs : infill_ei
#
# [mbo] 39: learning_rate=0.199; feature_fraction=0.538; min_data_in_leaf=3756; num_leaves=968; lambda_l1=0.121; lambda_l2=6.35 : y = 4.99e+07 : 49.0 secs : infill_ei
#
# [mbo] 40: learning_rate=0.199; feature_fraction=0.426; min_data_in_leaf=3930; num_leaves=545; lambda_l1=0.505; lambda_l2=4.6 : y = 5.15e+07 : 44.4 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 41: learning_rate=0.101; feature_fraction=0.396; min_data_in_leaf=3911; num_leaves=24; lambda_l1=0.012; lambda_l2=3.2 : y = 5.03e+07 : 49.0 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 42: learning_rate=0.0119; feature_fraction=0.817; min_data_in_leaf=4000; num_leaves=45; lambda_l1=9.97; lambda_l2=4.79 : y = 4.64e+07 : 141.3 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 43: learning_rate=0.2; feature_fraction=0.771; min_data_in_leaf=3996; num_leaves=65; lambda_l1=0.289; lambda_l2=1.91 : y = 5.11e+07 : 36.4 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 44: learning_rate=0.0958; feature_fraction=0.369; min_data_in_leaf=4000; num_leaves=1017; lambda_l1=0.00929; lambda_l2=0.187 : y = 5.02e+07 : 46.8 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 45: learning_rate=0.199; feature_fraction=0.622; min_data_in_leaf=3943; num_leaves=549; lambda_l1=0.011; lambda_l2=0.723 : y = 5.3e+07 : 34.9 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 46: learning_rate=0.199; feature_fraction=0.651; min_data_in_leaf=3977; num_leaves=82; lambda_l1=0.14; lambda_l2=0.009 : y = 5.28e+07 : 31.7 secs : infill_ei
#
# Warning message in (function (fn, nvars, max = FALSE, pop.size = 1000, max.generations = 100, :
# “Stopped because hard maximum generation limit was hit.”
# [mbo] 47: learning_rate=0.2; feature_fraction=0.654; min_data_in_leaf=3998; num_leaves=256; lambda_l1=0.0334; lambda_l2=0.495 : y = 5.21e+07 : 34.4 secs : infill_ei
#
# [mbo] 48: learning_rate=0.198; feature_fraction=0.583; min_data_in_leaf=3871; num_leaves=141; lambda_l1=0.0118; lambda_l2=0.2 : y = 5.29e+07 : 41.4 secs : infill_ei
#
# [mbo] 49: learning_rate=0.197; feature_fraction=0.394; min_data_in_leaf=3995; num_leaves=46; lambda_l1=0.123; lambda_l2=3.34 : y = 5.23e+07 : 42.0 secs : infill_ei
#
# [mbo] 50: learning_rate=0.2; feature_fraction=0.586; min_data_in_leaf=3795; num_leaves=737; lambda_l1=0.0506; lambda_l2=0.00446 : y = 5.1e+07 : 43.4 secs : infill_ei

# %% [markdown]
# #### Consolidacion
# Ahora voy a unir los mejores hiperparametros encontrados en la Bayesian Optimizacion con los hiperparametros que no optimice

# %%
fijos <- list(
  objective = "binary",
  metric = "custom",
  first_metric_only = TRUE,
  boost_from_average = TRUE,
  feature_pre_filter = FALSE,
  verbosity = -100,
  max_depth = -1,
  min_gain_to_split = 0.0,
  min_sum_hessian_in_leaf = 0.001,
  seed = PARAM$semilla_primigenia,
  num_iterations = PARAM$out$lgbm$mejor_iteracion
)

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# creo dataset final_train con todos los meses de entrenamiento
dfinal_train <- lgb.Dataset(
  data = data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$final_train, campos_buenos, with = FALSE]),
  label = dataset[foto_mes %in% PARAM$trainingstrategy$final_train, ifelse(clase_ternaria == "BAJA+2", 1L, 0L)],
  free_raw_data = FALSE
)

final_model <- lgb.train(
  data = dfinal_train,
  param = param_final,
  verbose = -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file = archivo_importancia,
  sep = "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[foto_mes %in% PARAM$trainingstrategy$future]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with = FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file = "prediccion.txt",
  sep = "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle,
    sep = ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste("-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
    "  semilla=", PARAM$semilla_primigenia,
    "'")

  linea <- paste(comando, competencia, arch, mensaje)

  salida <- system(linea, intern = TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial
# Successfully submitted to LaboI 2025 Virtual gerencial

# %%
# grabo los parametros
if (!require("yaml")) install.packages("yaml")
require("yaml")

write_yaml(PARAM, file = "PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Nov 14 02:48:30 PM 2025"
