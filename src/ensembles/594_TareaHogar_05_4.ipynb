# %% [markdown]
# <a href="https://colab.research.google.com/github/aleanaliaaustral-web/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  # Ensure the file is also copied to the Google Drive linked directory for R access
  cp $archivo_destino_bucket $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 11:30:21 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454457    77.7 1454457  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 59403
PARAM$semilla_primigenia <- 556088

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
#  HIPERPARÁMETROS OPTIMIZADOS SEGÚN EL PAPER
# ### ============================================================================
# # Basado en Imani & Arabnia (2023):
# # - LightGBM alcanzó ROC AUC = 91% con optimización
# # - Parámetros clave identificados:
# #   * num_leaves = 1169
# #   * max_depth = 10
# #   * lambda_l1 = 2.689e-7 (regularización L1 muy pequeña)
# #   * lambda_l2 = 7.238e-8 (regularización L2 muy pequeña)
# #   * feature_fraction = 0.8708
# #   * bagging_fraction = 0.6281
# #   * bagging_freq = 7

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
cat("\n")
cat("=========================================================================\n")
cat("CONFIGURACIÓN DE HIPERPARÁMETROS BASADA EN IMANI & ARABNIA (2023)\n")
cat("=========================================================================\n")
cat("Paper: LightGBM alcanzó ROC AUC = 91%\n")
cat("Optimizando 12 hiperparámetros críticos identificados en el paper\n")
cat("=========================================================================\n\n")

# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hyperparametertuning$hs <- makeParamSet(

  # === PARÁMETROS BÁSICOS (originales del profesor) ===
  # makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 2000L), # Duplicate definition
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeIntegerParam("num_leaves", lower= 31L, upper= 2048L),  # Paper: 1169
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L), # Correct definition

  # === PARÁMETROS DE MUESTREO (críticos según paper) ===
  makeNumericParam("feature_fraction", lower= 0.4, upper= 1.0),  # Paper: 0.8708
  makeNumericParam("bagging_fraction", lower= 0.4, upper= 1.0),  # Paper: 0.6281
  makeIntegerParam("bagging_freq", lower= 1L, upper= 10L),       # Paper: 7

  # === ESTRUCTURA DEL ÁRBOL ===
  makeIntegerParam("max_depth", lower= 3L, upper= 15L),          # Paper: 10

  # === REGULARIZACIÓN (MUY IMPORTANTE para evitar overfitting) ===
  # El paper encontró que valores MUY PEQUEÑOS pero NO CERO son óptimos
  makeNumericParam("lambda_l1", lower= 1e-8, upper= 5.0),  # ✅ Debe decir 5.0
  makeNumericParam("lambda_l2", lower= 1e-8, upper= 5.0),  # ✅ Debe decir 5.0

  # === OTROS PARÁMETROS IMPORTANTES ===
  makeIntegerParam("min_child_samples", lower= 5L, upper= 100L), # Paper: 8
  makeNumericParam("min_gain_to_split", lower= 0.0, upper= 1.0)
)

cat("Hiperparámetros a optimizar:\n")
cat("  1. num_iterations     [100, 2000]      - Número de árboles\n")
cat("  2. learning_rate      [0.01, 0.3]      - Tasa de aprendizaje\n")
cat("  3. num_leaves         [31, 2048]       - Hojas por árbol (paper: 1169)\n")
cat("  4. min_data_in_leaf   [1, 8000]        - Mínimo de datos por hoja\n")
cat("  5. feature_fraction   [0.4, 1.0]       - % features por árbol (paper: 0.87)\n")
cat("  6. bagging_fraction   [0.4, 1.0]       - % datos por árbol (paper: 0.63)\n")
cat("  7. bagging_freq       [1, 10]          - Frecuencia bagging (paper: 7)\n")
cat("  8. max_depth          [3, 15]          - Profundidad máxima (paper: 10)\n")
cat("  9. lambda_l1          [1e-8, 10]       - Regularización L1 (paper: 2.7e-7)\n")
cat(" 10. lambda_l2          [1e-8, 10]       - Regularización L2 (paper: 7.2e-8)\n")
cat(" 11. min_child_samples  [5, 100]         - Min samples en nodo hijo (paper: 8)\n")
cat(" 12. min_gain_to_split  [0, 1]           - Ganancia mínima para split\n")
cat("\n")

# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# RECOMENDACIÓN BASADA EN EL PAPER Y TIEMPO DISPONIBLE:
# - 30 iteraciones: Insuficiente para 12 hiperparámetros
# - 50 iteraciones: Balance óptimo tiempo/calidad ⭐
# - 100+ iteraciones: Ideal pero requiere mucho tiempo

PARAM$hyperparametertuning$iteraciones <- 50  # ⚠️ Ajustar según tiempo disponible

cat("Iteraciones de Optimización Bayesiana:", PARAM$hyperparametertuning$iteraciones, "\n")
cat("Tiempo estimado: ~", round(PARAM$hyperparametertuning$iteraciones * 2.5 / 60, 1), "horas\n")
cat("Con 50 iteraciones tendrás un buen balance entre calidad y tiempo.\n")
cat("\n")
# Out:
# =========================================================================
# CONFIGURACIÓN DE HIPERPARÁMETROS BASADA EN IMANI & ARABNIA (2023)
# =========================================================================
# Paper: LightGBM alcanzó ROC AUC = 91%
# Optimizando 12 hiperparámetros críticos identificados en el paper
# =========================================================================
#
# Hiperparámetros a optimizar:
#   1. num_iterations     [100, 2000]      - Número de árboles
#   2. learning_rate      [0.01, 0.3]      - Tasa de aprendizaje
#   3. num_leaves         [31, 2048]       - Hojas por árbol (paper: 1169)
#   4. min_data_in_leaf   [1, 8000]        - Mínimo de datos por hoja
#   5. feature_fraction   [0.4, 1.0]       - % features por árbol (paper: 0.87)
#   6. bagging_fraction   [0.4, 1.0]       - % datos por árbol (paper: 0.63)
#   7. bagging_freq       [1, 10]          - Frecuencia bagging (paper: 7)
#   8. max_depth          [3, 15]          - Profundidad máxima (paper: 10)
#   9. lambda_l1          [1e-8, 10]       - Regularización L1 (paper: 2.7e-7)
#  10. lambda_l2          [1e-8, 10]       - Regularización L2 (paper: 7.2e-8)
#  11. min_child_samples  [5, 100]         - Min samples en nodo hijo (paper: 8)
#  12. min_gain_to_split  [0, 1]           - Ganancia mínima para split
#
# Iteraciones de Optimización Bayesiana: 50
# Tiempo estimado: ~ 2.1 horas
# Con 50 iteraciones tendrás un buen balance entre calidad y tiempo.

# %%
PARAM$hyperparametertuning$hs <- makeParamSet(

  # === PARÁMETROS BÁSICOS (originales del profesor) ===
  makeIntegerParam("num_iterations", lower= 100L, upper= 2000L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeIntegerParam("num_leaves", lower= 31L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 2000L),

  # === PARÁMETROS DE MUESTREO (críticos según paper) ===
  makeNumericParam("feature_fraction", lower= 0.4, upper= 1.0),
  makeNumericParam("bagging_fraction", lower= 0.4, upper= 1.0),
  makeIntegerParam("bagging_freq", lower= 1L, upper= 10L),

  # === ESTRUCTURA DEL ÁRBOL ===
  makeIntegerParam("max_depth", lower= 3L, upper= 15L),

  # === REGULARIZACIÓN (MUY IMPORTANTE para evitar overfitting) ===
  makeNumericParam("lambda_l1", lower= 1e-8, upper= 5.0),
  makeNumericParam("lambda_l2", lower= 1e-8, upper= 5.0),

  # === OTROS PARÁMETROS IMPORTANTES ===
  makeIntegerParam("min_child_samples", lower= 5L, upper= 100L),
  makeNumericParam("min_gain_to_split", lower= 0.0, upper= 0.5)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

#setwd("/content/buckets/b1/exp") # Removed R setwd call
experimento_folder <- paste0("/content/buckets/b1/exp/HT", PARAM$experimento) # Use full path
dir.create(experimento_folder, showWarnings=FALSE)
#setwd( paste0("/content/buckets/b1/exp/", experimento_folder )) # Removed R setwd call

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83883
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization
# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hyperparametertuning$hs, # defined at the beginning of the program
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 04 11:28:33 AM 2025 AUC 0.923971387006472
#
# Tue Nov 04 11:30:38 AM 2025 AUC 0.923994912705929
#
# Tue Nov 04 11:32:34 AM 2025 AUC 0.92421142840272
#
# Tue Nov 04 11:34:18 AM 2025 AUC 0.925884281162171
#
# Tue Nov 04 11:35:23 AM 2025 AUC 0.925126465982616
#
# Tue Nov 04 11:37:31 AM 2025 AUC 0.92622602162435
#
# Tue Nov 04 11:38:16 AM 2025 AUC 0.924151578579666
#
# Tue Nov 04 11:39:04 AM 2025 AUC 0.92517824627879
#
# Tue Nov 04 11:40:00 AM 2025 AUC 0.924183810293357
#
# Tue Nov 04 11:41:10 AM 2025 AUC 0.921021100612121
#
# Tue Nov 04 11:42:44 AM 2025 AUC 0.919786890907656
#
# Tue Nov 04 11:44:21 AM 2025 AUC 0.924578735836326
#
# Tue Nov 04 11:46:02 AM 2025 AUC 0.928021296456903
#
# Tue Nov 04 11:47:03 AM 2025 AUC 0.922046675011784
#
# Tue Nov 04 11:48:30 AM 2025 AUC 0.926912402001512
#
# Tue Nov 04 11:50:20 AM 2025 AUC 0.924966953109506
#
# Tue Nov 04 11:51:09 AM 2025 AUC 0.917685261684389
#
# Tue Nov 04 11:53:14 AM 2025 AUC 0.92575087299484
#
# Tue Nov 04 11:54:32 AM 2025 AUC 0.924625783931275
#
# Tue Nov 04 11:55:48 AM 2025 AUC 0.925732634592053
#
# Tue Nov 04 11:56:49 AM 2025 AUC 0.919416530982051
#
# Tue Nov 04 11:57:51 AM 2025 AUC 0.924626370426712
#
# Tue Nov 04 12:00:33 PM 2025 AUC 0.926013869993527
#
# Tue Nov 04 12:02:36 PM 2025 AUC 0.924915571678342
#
# Tue Nov 04 12:03:34 PM 2025 AUC 0.925324391114693
#
# Tue Nov 04 12:04:36 PM 2025 AUC 0.923766545519486
#
# Tue Nov 04 12:06:15 PM 2025 AUC 0.924416864448087
#
# Tue Nov 04 12:07:37 PM 2025 AUC 0.927314710688705
#
# Tue Nov 04 12:10:02 PM 2025 AUC 0.923403824540272
#
# Tue Nov 04 12:11:50 PM 2025 AUC 0.921250825720817
#
# Tue Nov 04 12:13:40 PM 2025 AUC 0.925033512064998
#
# Tue Nov 04 12:14:25 PM 2025 AUC 0.92412575352606
#
# Tue Nov 04 12:15:12 PM 2025 AUC 0.922217853561411
#
# Tue Nov 04 12:16:37 PM 2025 AUC 0.924443615281244
#
# Tue Nov 04 12:18:01 PM 2025 AUC 0.920490349898981
#
# Tue Nov 04 12:19:06 PM 2025 AUC 0.922499236556497
#
# Tue Nov 04 12:21:17 PM 2025 AUC 0.922168674898518
#
# Tue Nov 04 12:22:04 PM 2025 AUC 0.92539832930533
#
# Tue Nov 04 12:23:12 PM 2025 AUC 0.922881483607736
#
# Tue Nov 04 12:24:54 PM 2025 AUC 0.925432886291253
#
# Tue Nov 04 12:26:54 PM 2025 AUC 0.92442470394719
#
# Tue Nov 04 12:28:24 PM 2025 AUC 0.925447442960658
#
# Tue Nov 04 12:29:39 PM 2025 AUC 0.912832879157929
#
# Tue Nov 04 12:32:29 PM 2025 AUC 0.930030729281617
#
# [mbo] 0: learning_rate=0.131; num_leaves=441; min_data_in_leaf=4850; feature_fraction=0.71; bagging_fraction=0.625; bagging_freq=8; max_depth=7; lambda_l1=2.98; lambda_l2=2.07; min_child_samples=84; min_gain_to_split=0.51 : y = 0.924 : 72.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.161; num_leaves=788; min_data_in_leaf=3682; feature_fraction=0.503; bagging_fraction=0.708; bagging_freq=6; max_depth=8; lambda_l1=0.891; lambda_l2=3.6; min_child_samples=58; min_gain_to_split=0.388 : y = 0.924 : 125.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0737; num_leaves=714; min_data_in_leaf=6044; feature_fraction=0.467; bagging_fraction=0.658; bagging_freq=4; max_depth=14; lambda_l1=2.86; lambda_l2=1.93; min_child_samples=53; min_gain_to_split=0.415 : y = 0.924 : 115.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0542; num_leaves=912; min_data_in_leaf=3588; feature_fraction=0.607; bagging_fraction=0.695; bagging_freq=4; max_depth=11; lambda_l1=2.82; lambda_l2=2.03; min_child_samples=60; min_gain_to_split=0.921 : y = 0.926 : 104.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.195; num_leaves=1458; min_data_in_leaf=3127; feature_fraction=0.917; bagging_fraction=0.864; bagging_freq=5; max_depth=10; lambda_l1=2.17; lambda_l2=4.66; min_child_samples=70; min_gain_to_split=0.47 : y = 0.925 : 65.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0988; num_leaves=729; min_data_in_leaf=2332; feature_fraction=0.474; bagging_fraction=0.878; bagging_freq=8; max_depth=13; lambda_l1=0.596; lambda_l2=2.39; min_child_samples=41; min_gain_to_split=0.492 : y = 0.926 : 127.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.176; num_leaves=875; min_data_in_leaf=2447; feature_fraction=0.754; bagging_fraction=0.543; bagging_freq=6; max_depth=11; lambda_l1=3.63; lambda_l2=0.12; min_child_samples=20; min_gain_to_split=0.982 : y = 0.924 : 45.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.242; num_leaves=977; min_data_in_leaf=4357; feature_fraction=0.732; bagging_fraction=0.952; bagging_freq=8; max_depth=9; lambda_l1=4.87; lambda_l2=3.11; min_child_samples=32; min_gain_to_split=0.633 : y = 0.925 : 48.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.23; num_leaves=1430; min_data_in_leaf=1195; feature_fraction=0.78; bagging_fraction=0.759; bagging_freq=8; max_depth=11; lambda_l1=2.49; lambda_l2=1.73; min_child_samples=75; min_gain_to_split=0.288 : y = 0.924 : 55.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.12; num_leaves=385; min_data_in_leaf=5894; feature_fraction=0.574; bagging_fraction=0.449; bagging_freq=10; max_depth=11; lambda_l1=3.72; lambda_l2=4.07; min_child_samples=88; min_gain_to_split=0.306 : y = 0.921 : 70.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.288; num_leaves=478; min_data_in_leaf=6604; feature_fraction=0.596; bagging_fraction=0.595; bagging_freq=3; max_depth=15; lambda_l1=0.754; lambda_l2=2.3; min_child_samples=33; min_gain_to_split=0.329 : y = 0.92 : 94.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.174; num_leaves=1512; min_data_in_leaf=1618; feature_fraction=0.984; bagging_fraction=0.636; bagging_freq=6; max_depth=12; lambda_l1=3.76; lambda_l2=3.97; min_child_samples=38; min_gain_to_split=0.0876 : y = 0.925 : 97.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.165; num_leaves=1058; min_data_in_leaf=4045; feature_fraction=0.881; bagging_fraction=0.936; bagging_freq=9; max_depth=5; lambda_l1=2.32; lambda_l2=3; min_child_samples=67; min_gain_to_split=0.0468 : y = 0.928 : 101.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.25; num_leaves=840; min_data_in_leaf=835; feature_fraction=0.787; bagging_fraction=0.56; bagging_freq=6; max_depth=3; lambda_l1=1.95; lambda_l2=1.07; min_child_samples=19; min_gain_to_split=0.802 : y = 0.922 : 61.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0601; num_leaves=1209; min_data_in_leaf=675; feature_fraction=0.755; bagging_fraction=0.465; bagging_freq=3; max_depth=6; lambda_l1=1.43; lambda_l2=2.57; min_child_samples=72; min_gain_to_split=0.835 : y = 0.927 : 86.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0381; num_leaves=1653; min_data_in_leaf=6243; feature_fraction=0.858; bagging_fraction=0.988; bagging_freq=5; max_depth=6; lambda_l1=4.27; lambda_l2=0.448; min_child_samples=70; min_gain_to_split=0.127 : y = 0.925 : 110.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.223; num_leaves=1749; min_data_in_leaf=7198; feature_fraction=0.839; bagging_fraction=0.502; bagging_freq=10; max_depth=10; lambda_l1=0.485; lambda_l2=0.84; min_child_samples=17; min_gain_to_split=0.869 : y = 0.918 : 48.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0805; num_leaves=246; min_data_in_leaf=5155; feature_fraction=0.693; bagging_fraction=0.833; bagging_freq=2; max_depth=13; lambda_l1=1.73; lambda_l2=2.72; min_child_samples=81; min_gain_to_split=0.356 : y = 0.926 : 124.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.123; num_leaves=1795; min_data_in_leaf=1082; feature_fraction=0.918; bagging_fraction=0.564; bagging_freq=9; max_depth=5; lambda_l1=1.22; lambda_l2=0.108; min_child_samples=42; min_gain_to_split=0.194 : y = 0.925 : 78.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.044; num_leaves=1578; min_data_in_leaf=1436; feature_fraction=0.644; bagging_fraction=0.495; bagging_freq=8; max_depth=7; lambda_l1=4.15; lambda_l2=3.74; min_child_samples=46; min_gain_to_split=0.536 : y = 0.926 : 75.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.298; num_leaves=521; min_data_in_leaf=3370; feature_fraction=0.821; bagging_fraction=0.425; bagging_freq=5; max_depth=6; lambda_l1=1.55; lambda_l2=3.27; min_child_samples=90; min_gain_to_split=0.708 : y = 0.919 : 61.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0855; num_leaves=591; min_data_in_leaf=5729; feature_fraction=0.83; bagging_fraction=0.771; bagging_freq=5; max_depth=12; lambda_l1=4.56; lambda_l2=0.795; min_child_samples=11; min_gain_to_split=0.772 : y = 0.925 : 61.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.148; num_leaves=1596; min_data_in_leaf=2066; feature_fraction=0.584; bagging_fraction=0.891; bagging_freq=3; max_depth=10; lambda_l1=1.6; lambda_l2=2.83; min_child_samples=26; min_gain_to_split=0.103 : y = 0.926 : 162.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.139; num_leaves=2046; min_data_in_leaf=5056; feature_fraction=0.446; bagging_fraction=0.808; bagging_freq=1; max_depth=4; lambda_l1=3.13; lambda_l2=4.84; min_child_samples=83; min_gain_to_split=0.162 : y = 0.925 : 123.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.155; num_leaves=1330; min_data_in_leaf=2786; feature_fraction=0.961; bagging_fraction=0.917; bagging_freq=9; max_depth=15; lambda_l1=0.282; lambda_l2=1.4; min_child_samples=29; min_gain_to_split=0.586 : y = 0.925 : 57.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.108; num_leaves=1887; min_data_in_leaf=7837; feature_fraction=0.651; bagging_fraction=0.754; bagging_freq=7; max_depth=5; lambda_l1=2.6; lambda_l2=2.21; min_child_samples=77; min_gain_to_split=0.787 : y = 0.924 : 62.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.189; num_leaves=210; min_data_in_leaf=3938; feature_fraction=0.519; bagging_fraction=0.79; bagging_freq=10; max_depth=7; lambda_l1=1.28; lambda_l2=4.1; min_child_samples=49; min_gain_to_split=0.671 : y = 0.924 : 98.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.187; num_leaves=87; min_data_in_leaf=401; feature_fraction=0.625; bagging_fraction=0.818; bagging_freq=2; max_depth=8; lambda_l1=3.46; lambda_l2=4.38; min_child_samples=94; min_gain_to_split=0.55 : y = 0.927 : 82.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.261; num_leaves=1399; min_data_in_leaf=6944; feature_fraction=0.532; bagging_fraction=0.851; bagging_freq=2; max_depth=6; lambda_l1=4.9; lambda_l2=0.461; min_child_samples=23; min_gain_to_split=0.267 : y = 0.923 : 145.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.239; num_leaves=638; min_data_in_leaf=2698; feature_fraction=0.686; bagging_fraction=0.414; bagging_freq=1; max_depth=13; lambda_l1=3.99; lambda_l2=2.87; min_child_samples=36; min_gain_to_split=0.225 : y = 0.921 : 108.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0932; num_leaves=998; min_data_in_leaf=1809; feature_fraction=0.546; bagging_fraction=0.532; bagging_freq=2; max_depth=3; lambda_l1=2.06; lambda_l2=4.69; min_child_samples=9; min_gain_to_split=0.892 : y = 0.925 : 109.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.255; num_leaves=129; min_data_in_leaf=4447; feature_fraction=0.715; bagging_fraction=0.735; bagging_freq=10; max_depth=9; lambda_l1=4.36; lambda_l2=0.589; min_child_samples=86; min_gain_to_split=0.433 : y = 0.924 : 45.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.28; num_leaves=1244; min_data_in_leaf=121; feature_fraction=0.998; bagging_fraction=0.922; bagging_freq=4; max_depth=14; lambda_l1=4.77; lambda_l2=0.327; min_child_samples=10; min_gain_to_split=0.728 : y = 0.922 : 46.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0253; num_leaves=540; min_data_in_leaf=5325; feature_fraction=0.896; bagging_fraction=0.686; bagging_freq=3; max_depth=3; lambda_l1=1.92; lambda_l2=1.64; min_child_samples=46; min_gain_to_split=0.381 : y = 0.924 : 85.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.112; num_leaves=335; min_data_in_leaf=7531; feature_fraction=0.41; bagging_fraction=0.613; bagging_freq=6; max_depth=9; lambda_l1=4.43; lambda_l2=3.77; min_child_samples=98; min_gain_to_split=0.974 : y = 0.92 : 84.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.27; num_leaves=1976; min_data_in_leaf=6537; feature_fraction=0.951; bagging_fraction=0.664; bagging_freq=9; max_depth=3; lambda_l1=0.394; lambda_l2=3.37; min_child_samples=63; min_gain_to_split=0.152 : y = 0.922 : 65.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0113; num_leaves=1829; min_data_in_leaf=4663; feature_fraction=0.426; bagging_fraction=0.474; bagging_freq=1; max_depth=9; lambda_l1=0.154; lambda_l2=1.17; min_child_samples=94; min_gain_to_split=0.0291 : y = 0.922 : 130.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.215; num_leaves=40; min_data_in_leaf=6792; feature_fraction=0.67; bagging_fraction=0.984; bagging_freq=1; max_depth=8; lambda_l1=0.111; lambda_l2=1.5; min_child_samples=51; min_gain_to_split=0.936 : y = 0.925 : 47.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0357; num_leaves=1292; min_data_in_leaf=5500; feature_fraction=0.933; bagging_fraction=0.515; bagging_freq=4; max_depth=14; lambda_l1=3.93; lambda_l2=4.47; min_child_samples=57; min_gain_to_split=0.688 : y = 0.923 : 67.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0641; num_leaves=1723; min_data_in_leaf=2970; feature_fraction=0.439; bagging_fraction=0.589; bagging_freq=7; max_depth=15; lambda_l1=0.978; lambda_l2=1.33; min_child_samples=14; min_gain_to_split=0.841 : y = 0.925 : 102.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.206; num_leaves=1144; min_data_in_leaf=7428; feature_fraction=0.495; bagging_fraction=0.969; bagging_freq=7; max_depth=15; lambda_l1=2.63; lambda_l2=4.9; min_child_samples=65; min_gain_to_split=0.239 : y = 0.924 : 119.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.213; num_leaves=1913; min_data_in_leaf=1987; feature_fraction=0.805; bagging_fraction=0.723; bagging_freq=2; max_depth=5; lambda_l1=3.37; lambda_l2=0.942; min_child_samples=99; min_gain_to_split=0.61 : y = 0.925 : 90.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.282; num_leaves=290; min_data_in_leaf=7752; feature_fraction=0.552; bagging_fraction=0.438; bagging_freq=5; max_depth=4; lambda_l1=3.23; lambda_l2=3.5; min_child_samples=5; min_gain_to_split=0.655 : y = 0.913 : 75.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0223; num_leaves=1098; min_data_in_leaf=354; feature_fraction=0.876; bagging_fraction=0.838; bagging_freq=10; max_depth=12; lambda_l1=1.09; lambda_l2=4.3; min_child_samples=28; min_gain_to_split=0.00053 : y = 0.93 : 170.0 secs : initdesign
#
# Tue Nov 04 12:34:01 PM 2025 AUC 0.930147406010246
#
# [mbo] 1: learning_rate=0.0474; num_leaves=504; min_data_in_leaf=174; feature_fraction=0.916; bagging_fraction=0.957; bagging_freq=10; max_depth=4; lambda_l1=1.73; lambda_l2=4.97; min_child_samples=78; min_gain_to_split=0.172 : y = 0.93 : 91.3 secs : infill_ei
#
# Tue Nov 04 12:36:29 PM 2025 AUC 0.929965292423442
#
# [mbo] 2: learning_rate=0.0376; num_leaves=686; min_data_in_leaf=21; feature_fraction=0.866; bagging_fraction=0.944; bagging_freq=10; max_depth=7; lambda_l1=2.18; lambda_l2=4.74; min_child_samples=25; min_gain_to_split=0.0184 : y = 0.93 : 147.1 secs : infill_ei
#
# Tue Nov 04 12:39:19 PM 2025 AUC 0.929713809995137
#
# [mbo] 3: learning_rate=0.0107; num_leaves=72; min_data_in_leaf=4; feature_fraction=0.96; bagging_fraction=0.862; bagging_freq=10; max_depth=12; lambda_l1=1.59; lambda_l2=4.97; min_child_samples=58; min_gain_to_split=0.0814 : y = 0.93 : 169.2 secs : infill_ei
#
# Tue Nov 04 12:40:36 PM 2025 AUC 0.929382425243611
#
# [mbo] 4: learning_rate=0.0184; num_leaves=1377; min_data_in_leaf=267; feature_fraction=0.702; bagging_fraction=0.898; bagging_freq=10; max_depth=3; lambda_l1=3.35; lambda_l2=4.7; min_child_samples=68; min_gain_to_split=0.0117 : y = 0.929 : 76.2 secs : infill_ei
#
# Tue Nov 04 12:42:36 PM 2025 AUC 0.930025575921647
#
# [mbo] 5: learning_rate=0.0141; num_leaves=917; min_data_in_leaf=20; feature_fraction=0.985; bagging_fraction=0.853; bagging_freq=10; max_depth=6; lambda_l1=1.55; lambda_l2=4.59; min_child_samples=67; min_gain_to_split=0.0717 : y = 0.93 : 119.3 secs : infill_ei
#
# Tue Nov 04 12:45:22 PM 2025 AUC 0.928767485820998
#
# [mbo] 6: learning_rate=0.0147; num_leaves=925; min_data_in_leaf=111; feature_fraction=0.841; bagging_fraction=0.953; bagging_freq=10; max_depth=10; lambda_l1=0.357; lambda_l2=4.76; min_child_samples=70; min_gain_to_split=0.242 : y = 0.929 : 165.7 secs : infill_ei
#
# Tue Nov 04 12:47:03 PM 2025 AUC 0.929684308219731
#
# [mbo] 7: learning_rate=0.0528; num_leaves=308; min_data_in_leaf=499; feature_fraction=0.887; bagging_fraction=0.87; bagging_freq=10; max_depth=5; lambda_l1=2.46; lambda_l2=4.16; min_child_samples=63; min_gain_to_split=0.0143 : y = 0.93 : 100.0 secs : infill_ei
#
# Tue Nov 04 12:48:28 PM 2025 AUC 0.929077771882054
#
# [mbo] 8: learning_rate=0.0252; num_leaves=640; min_data_in_leaf=17; feature_fraction=0.857; bagging_fraction=0.884; bagging_freq=5; max_depth=3; lambda_l1=1.81; lambda_l2=4.89; min_child_samples=48; min_gain_to_split=0.0567 : y = 0.929 : 85.2 secs : infill_ei
#
# Tue Nov 04 12:51:25 PM 2025 AUC 0.928523189487078
#
# [mbo] 9: learning_rate=0.0323; num_leaves=989; min_data_in_leaf=101; feature_fraction=0.96; bagging_fraction=0.821; bagging_freq=10; max_depth=12; lambda_l1=2.34; lambda_l2=5; min_child_samples=42; min_gain_to_split=0.0131 : y = 0.929 : 176.2 secs : infill_ei
#
# Tue Nov 04 12:53:26 PM 2025 AUC 0.929615658004009
#
# [mbo] 10: learning_rate=0.0115; num_leaves=511; min_data_in_leaf=558; feature_fraction=0.869; bagging_fraction=0.923; bagging_freq=10; max_depth=7; lambda_l1=1.39; lambda_l2=3.95; min_child_samples=46; min_gain_to_split=0.0248 : y = 0.93 : 120.2 secs : infill_ei
#
# Tue Nov 04 12:55:19 PM 2025 AUC 0.930159104123188
#
# [mbo] 11: learning_rate=0.0102; num_leaves=424; min_data_in_leaf=112; feature_fraction=0.951; bagging_fraction=0.864; bagging_freq=10; max_depth=6; lambda_l1=0.178; lambda_l2=4.73; min_child_samples=13; min_gain_to_split=0.103 : y = 0.93 : 112.4 secs : infill_ei
#
# Tue Nov 04 12:56:35 PM 2025 AUC 0.92940180065642
#
# [mbo] 12: learning_rate=0.0357; num_leaves=973; min_data_in_leaf=16; feature_fraction=0.701; bagging_fraction=0.862; bagging_freq=10; max_depth=3; lambda_l1=1.41; lambda_l2=4.18; min_child_samples=25; min_gain_to_split=0.135 : y = 0.929 : 75.2 secs : infill_ei
#
# Tue Nov 04 12:58:07 PM 2025 AUC 0.930037894411854
#
# [mbo] 13: learning_rate=0.104; num_leaves=848; min_data_in_leaf=31; feature_fraction=0.842; bagging_fraction=0.893; bagging_freq=10; max_depth=4; lambda_l1=0.857; lambda_l2=4.72; min_child_samples=96; min_gain_to_split=0.00473 : y = 0.93 : 90.6 secs : infill_ei
#
# Tue Nov 04 12:59:44 PM 2025 AUC 0.92870771810149
#
# [mbo] 14: learning_rate=0.0334; num_leaves=81; min_data_in_leaf=11; feature_fraction=0.96; bagging_fraction=0.866; bagging_freq=10; max_depth=5; lambda_l1=1.11; lambda_l2=4.63; min_child_samples=99; min_gain_to_split=0.645 : y = 0.929 : 96.4 secs : infill_ei
#
# Tue Nov 04 01:01:44 PM 2025 AUC 0.930164317175234
#
# [mbo] 15: learning_rate=0.0141; num_leaves=1245; min_data_in_leaf=796; feature_fraction=0.981; bagging_fraction=0.894; bagging_freq=10; max_depth=7; lambda_l1=0.717; lambda_l2=4.92; min_child_samples=5; min_gain_to_split=0.0187 : y = 0.93 : 119.5 secs : infill_ei
#
# Tue Nov 04 01:03:08 PM 2025 AUC 0.929415588353683
#
# [mbo] 16: learning_rate=0.136; num_leaves=89; min_data_in_leaf=60; feature_fraction=0.918; bagging_fraction=0.985; bagging_freq=7; max_depth=3; lambda_l1=4.17; lambda_l2=4.25; min_child_samples=100; min_gain_to_split=0.0259 : y = 0.929 : 83.2 secs : infill_ei
#
# Tue Nov 04 01:04:32 PM 2025 AUC 0.929204377870469
#
# [mbo] 17: learning_rate=0.0976; num_leaves=1111; min_data_in_leaf=95; feature_fraction=0.817; bagging_fraction=0.985; bagging_freq=10; max_depth=3; lambda_l1=2.99; lambda_l2=4.61; min_child_samples=93; min_gain_to_split=0.0289 : y = 0.929 : 83.1 secs : infill_ei
#
# Tue Nov 04 01:07:04 PM 2025 AUC 0.929053047716376
#
# [mbo] 18: learning_rate=0.0326; num_leaves=388; min_data_in_leaf=906; feature_fraction=0.88; bagging_fraction=0.871; bagging_freq=9; max_depth=14; lambda_l1=0.425; lambda_l2=4.7; min_child_samples=5; min_gain_to_split=0.000347 : y = 0.929 : 151.7 secs : infill_ei
#
# Tue Nov 04 01:08:39 PM 2025 AUC 0.92984466062236
#
# [mbo] 19: learning_rate=0.0424; num_leaves=32; min_data_in_leaf=76; feature_fraction=0.833; bagging_fraction=0.947; bagging_freq=10; max_depth=4; lambda_l1=3.84; lambda_l2=5; min_child_samples=87; min_gain_to_split=0.00689 : y = 0.93 : 93.9 secs : infill_ei
#
# Tue Nov 04 01:10:00 PM 2025 AUC 0.927420920806795
#
# [mbo] 20: learning_rate=0.235; num_leaves=46; min_data_in_leaf=31; feature_fraction=0.873; bagging_fraction=0.975; bagging_freq=9; max_depth=3; lambda_l1=0.333; lambda_l2=4.93; min_child_samples=79; min_gain_to_split=0.00378 : y = 0.927 : 80.9 secs : infill_ei
#
# Tue Nov 04 01:11:59 PM 2025 AUC 0.930734861810051
#
# [mbo] 21: learning_rate=0.019; num_leaves=1337; min_data_in_leaf=28; feature_fraction=0.877; bagging_fraction=0.846; bagging_freq=10; max_depth=6; lambda_l1=0.563; lambda_l2=4.02; min_child_samples=26; min_gain_to_split=0.026 : y = 0.931 : 118.3 secs : infill_ei
#
# Tue Nov 04 01:16:02 PM 2025 AUC 0.929908031996858
#
# [mbo] 22: learning_rate=0.0107; num_leaves=1788; min_data_in_leaf=19; feature_fraction=0.833; bagging_fraction=0.843; bagging_freq=10; max_depth=12; lambda_l1=0.00602; lambda_l2=4.83; min_child_samples=17; min_gain_to_split=0.0119 : y = 0.93 : 242.2 secs : infill_ei
#
# Tue Nov 04 01:17:06 PM 2025 AUC 0.929616163379427
#
# [mbo] 23: learning_rate=0.0928; num_leaves=86; min_data_in_leaf=6; feature_fraction=0.999; bagging_fraction=0.965; bagging_freq=10; max_depth=3; lambda_l1=4.24; lambda_l2=4.1; min_child_samples=37; min_gain_to_split=0.235 : y = 0.93 : 62.9 secs : infill_ei
#
# Tue Nov 04 01:19:43 PM 2025 AUC 0.928456138852916
#
# [mbo] 24: learning_rate=0.0289; num_leaves=1058; min_data_in_leaf=56; feature_fraction=0.943; bagging_fraction=0.866; bagging_freq=8; max_depth=8; lambda_l1=0.0584; lambda_l2=2.46; min_child_samples=17; min_gain_to_split=0.00262 : y = 0.928 : 156.4 secs : infill_ei
#
# Tue Nov 04 01:21:43 PM 2025 AUC 0.927861685480388
#
# [mbo] 25: learning_rate=0.0197; num_leaves=1968; min_data_in_leaf=1652; feature_fraction=0.913; bagging_fraction=0.842; bagging_freq=10; max_depth=9; lambda_l1=0.151; lambda_l2=4.06; min_child_samples=58; min_gain_to_split=0.00989 : y = 0.928 : 118.4 secs : infill_ei
#
# Tue Nov 04 01:23:04 PM 2025 AUC 0.928020253670419
#
# [mbo] 26: learning_rate=0.116; num_leaves=90; min_data_in_leaf=3510; feature_fraction=0.856; bagging_fraction=0.995; bagging_freq=10; max_depth=5; lambda_l1=4.64; lambda_l2=4.76; min_child_samples=55; min_gain_to_split=0.0211 : y = 0.928 : 80.6 secs : infill_ei
#
# Tue Nov 04 01:24:36 PM 2025 AUC 0.927449177480422
#
# [mbo] 27: learning_rate=0.0954; num_leaves=44; min_data_in_leaf=7; feature_fraction=0.991; bagging_fraction=0.962; bagging_freq=1; max_depth=6; lambda_l1=1.28; lambda_l2=4.37; min_child_samples=78; min_gain_to_split=0.0345 : y = 0.927 : 90.3 secs : infill_ei
#
# Tue Nov 04 01:25:25 PM 2025 AUC 0.927828950122876
#
# [mbo] 28: learning_rate=0.12; num_leaves=390; min_data_in_leaf=116; feature_fraction=0.866; bagging_fraction=0.961; bagging_freq=10; max_depth=4; lambda_l1=4.96; lambda_l2=4.51; min_child_samples=98; min_gain_to_split=0.948 : y = 0.928 : 48.3 secs : infill_ei
#
# Tue Nov 04 01:27:33 PM 2025 AUC 0.928555950821113
#
# [mbo] 29: learning_rate=0.0106; num_leaves=99; min_data_in_leaf=2; feature_fraction=0.731; bagging_fraction=0.616; bagging_freq=2; max_depth=15; lambda_l1=3.84; lambda_l2=4.28; min_child_samples=19; min_gain_to_split=0.803 : y = 0.929 : 127.7 secs : infill_ei
#
# Tue Nov 04 01:29:16 PM 2025 AUC 0.930117438353276
#
# [mbo] 30: learning_rate=0.01; num_leaves=40; min_data_in_leaf=5; feature_fraction=0.706; bagging_fraction=0.575; bagging_freq=10; max_depth=15; lambda_l1=1.43; lambda_l2=2.23; min_child_samples=17; min_gain_to_split=0.695 : y = 0.93 : 101.6 secs : infill_ei
#
# Tue Nov 04 01:30:57 PM 2025 AUC 0.930782539905594
#
# [mbo] 31: learning_rate=0.0106; num_leaves=36; min_data_in_leaf=27; feature_fraction=0.757; bagging_fraction=0.584; bagging_freq=9; max_depth=15; lambda_l1=1.34; lambda_l2=3.89; min_child_samples=83; min_gain_to_split=0.619 : y = 0.931 : 100.8 secs : infill_ei
#
# Tue Nov 04 01:33:09 PM 2025 AUC 0.930933392509879
#
# [mbo] 32: learning_rate=0.0112; num_leaves=77; min_data_in_leaf=26; feature_fraction=0.728; bagging_fraction=0.615; bagging_freq=8; max_depth=14; lambda_l1=0.685; lambda_l2=4.48; min_child_samples=36; min_gain_to_split=0.58 : y = 0.931 : 130.8 secs : infill_ei
#
# Tue Nov 04 01:35:44 PM 2025 AUC 0.929318826196976
#
# [mbo] 33: learning_rate=0.0135; num_leaves=248; min_data_in_leaf=156; feature_fraction=0.691; bagging_fraction=0.633; bagging_freq=10; max_depth=15; lambda_l1=1.15; lambda_l2=3.59; min_child_samples=79; min_gain_to_split=0.053 : y = 0.929 : 154.4 secs : infill_ei
#
# Tue Nov 04 01:37:55 PM 2025 AUC 0.928637080895094
#
# [mbo] 34: learning_rate=0.0103; num_leaves=1347; min_data_in_leaf=59; feature_fraction=0.734; bagging_fraction=0.571; bagging_freq=10; max_depth=14; lambda_l1=0.14; lambda_l2=4.36; min_child_samples=25; min_gain_to_split=0.832 : y = 0.929 : 130.0 secs : infill_ei
#
# Tue Nov 04 01:39:42 PM 2025 AUC 0.929929384328035
#
# [mbo] 35: learning_rate=0.0109; num_leaves=35; min_data_in_leaf=14; feature_fraction=0.87; bagging_fraction=0.615; bagging_freq=8; max_depth=14; lambda_l1=1.57; lambda_l2=3.67; min_child_samples=46; min_gain_to_split=0.573 : y = 0.93 : 106.3 secs : infill_ei
#
# Tue Nov 04 01:40:56 PM 2025 AUC 0.928046373545614
#
# [mbo] 36: learning_rate=0.0103; num_leaves=1422; min_data_in_leaf=63; feature_fraction=0.911; bagging_fraction=0.814; bagging_freq=10; max_depth=3; lambda_l1=2.43; lambda_l2=4.9; min_child_samples=11; min_gain_to_split=0.0296 : y = 0.928 : 73.2 secs : infill_ei
#
# Tue Nov 04 01:43:08 PM 2025 AUC 0.929244825966677
#
# [mbo] 37: learning_rate=0.0186; num_leaves=60; min_data_in_leaf=6; feature_fraction=0.528; bagging_fraction=0.556; bagging_freq=4; max_depth=14; lambda_l1=0.89; lambda_l2=2.73; min_child_samples=84; min_gain_to_split=0.802 : y = 0.929 : 131.5 secs : infill_ei
#
# Tue Nov 04 01:44:50 PM 2025 AUC 0.930013780010124
#
# [mbo] 38: learning_rate=0.0152; num_leaves=73; min_data_in_leaf=25; feature_fraction=0.718; bagging_fraction=0.56; bagging_freq=10; max_depth=14; lambda_l1=1.32; lambda_l2=4.36; min_child_samples=52; min_gain_to_split=0.878 : y = 0.93 : 100.7 secs : infill_ei
#
# Tue Nov 04 01:47:22 PM 2025 AUC 0.929472901392078
#
# [mbo] 39: learning_rate=0.0127; num_leaves=276; min_data_in_leaf=12; feature_fraction=0.872; bagging_fraction=0.719; bagging_freq=9; max_depth=15; lambda_l1=0.0967; lambda_l2=4.84; min_child_samples=20; min_gain_to_split=0.632 : y = 0.929 : 151.1 secs : infill_ei
#
# Tue Nov 04 01:49:49 PM 2025 AUC 0.929071843546946
#
# [mbo] 40: learning_rate=0.0173; num_leaves=157; min_data_in_leaf=4; feature_fraction=0.712; bagging_fraction=0.577; bagging_freq=5; max_depth=13; lambda_l1=0.637; lambda_l2=4.95; min_child_samples=74; min_gain_to_split=0.329 : y = 0.929 : 145.9 secs : infill_ei
#
# Tue Nov 04 01:52:13 PM 2025 AUC 0.929643721722724
#
# [mbo] 41: learning_rate=0.0183; num_leaves=117; min_data_in_leaf=39; feature_fraction=0.495; bagging_fraction=0.756; bagging_freq=10; max_depth=15; lambda_l1=3.65; lambda_l2=4.19; min_child_samples=83; min_gain_to_split=0.517 : y = 0.93 : 143.1 secs : infill_ei
#
# Tue Nov 04 01:54:00 PM 2025 AUC 0.93027846485633
#
# [mbo] 42: learning_rate=0.0145; num_leaves=1603; min_data_in_leaf=28; feature_fraction=0.863; bagging_fraction=0.914; bagging_freq=7; max_depth=5; lambda_l1=0.381; lambda_l2=4.99; min_child_samples=28; min_gain_to_split=0.431 : y = 0.93 : 105.8 secs : infill_ei
#
# Tue Nov 04 01:56:00 PM 2025 AUC 0.929746363948177
#
# [mbo] 43: learning_rate=0.0101; num_leaves=109; min_data_in_leaf=620; feature_fraction=0.477; bagging_fraction=0.605; bagging_freq=9; max_depth=15; lambda_l1=2.9; lambda_l2=2.89; min_child_samples=69; min_gain_to_split=0.68 : y = 0.93 : 119.4 secs : infill_ei
#
# Tue Nov 04 01:58:03 PM 2025 AUC 0.929841119948802
#
# [mbo] 44: learning_rate=0.0249; num_leaves=1475; min_data_in_leaf=11; feature_fraction=0.717; bagging_fraction=0.9; bagging_freq=9; max_depth=6; lambda_l1=0.66; lambda_l2=4.78; min_child_samples=33; min_gain_to_split=0.0347 : y = 0.93 : 122.0 secs : infill_ei
#
# Tue Nov 04 01:59:51 PM 2025 AUC 0.928499812095852
#
# [mbo] 45: learning_rate=0.0165; num_leaves=1084; min_data_in_leaf=1023; feature_fraction=0.816; bagging_fraction=0.881; bagging_freq=10; max_depth=6; lambda_l1=1.44; lambda_l2=4.87; min_child_samples=27; min_gain_to_split=0.377 : y = 0.928 : 106.6 secs : infill_ei
#
# Tue Nov 04 02:01:13 PM 2025 AUC 0.928538583075489
#
# [mbo] 46: learning_rate=0.0762; num_leaves=468; min_data_in_leaf=18; feature_fraction=0.637; bagging_fraction=0.911; bagging_freq=9; max_depth=3; lambda_l1=4.26; lambda_l2=3.57; min_child_samples=99; min_gain_to_split=0.294 : y = 0.929 : 81.4 secs : infill_ei
#
# Tue Nov 04 02:03:25 PM 2025 AUC 0.93006368550747
#
# [mbo] 47: learning_rate=0.0107; num_leaves=358; min_data_in_leaf=23; feature_fraction=0.607; bagging_fraction=0.609; bagging_freq=9; max_depth=15; lambda_l1=4.57; lambda_l2=0.32; min_child_samples=80; min_gain_to_split=0.282 : y = 0.93 : 130.3 secs : infill_ei
#
# Tue Nov 04 02:05:20 PM 2025 AUC 0.930203738001226
#
# [mbo] 48: learning_rate=0.0312; num_leaves=32; min_data_in_leaf=7; feature_fraction=0.581; bagging_fraction=0.728; bagging_freq=6; max_depth=15; lambda_l1=4.39; lambda_l2=0.41; min_child_samples=83; min_gain_to_split=0.813 : y = 0.93 : 114.7 secs : infill_ei
#
# Tue Nov 04 02:06:48 PM 2025 AUC 0.928748580502259
#
# [mbo] 49: learning_rate=0.0658; num_leaves=31; min_data_in_leaf=15; feature_fraction=0.693; bagging_fraction=0.63; bagging_freq=8; max_depth=15; lambda_l1=1.01; lambda_l2=4.15; min_child_samples=62; min_gain_to_split=0.673 : y = 0.929 : 87.1 secs : infill_ei
#
# Tue Nov 04 02:09:10 PM 2025 AUC 0.931231917521665
#
# [mbo] 50: learning_rate=0.0101; num_leaves=38; min_data_in_leaf=23; feature_fraction=0.513; bagging_fraction=0.641; bagging_freq=6; max_depth=8; lambda_l1=3.51; lambda_l2=0.611; min_child_samples=95; min_gain_to_split=0.694 : y = 0.931 : 140.2 secs : infill_ei

# %%
# Attempt to install packages from CRAN
install.packages(c("primes", "rlist", "DiceKriging", "mlrMBO"), dependencies = TRUE)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘TH.data’, ‘plotrix’, ‘patchwork’, ‘libcoin’, ‘matrixStats’, ‘multcomp’, ‘lazyeval’, ‘iterators’, ‘Formula’, ‘plotmo’, ‘ggstats’, ‘igraph’, ‘mvtnorm’, ‘modeltools’, ‘strucchange’, ‘coin’, ‘zoo’, ‘sandwich’, ‘plyr’, ‘rex’, ‘stringdist’, ‘rgenoud’, ‘foreach’, ‘doParallel’, ‘numDeriv’, ‘cmaesr’, ‘earth’, ‘emoa’, ‘GGally’, ‘gridExtra’, ‘kernlab’, ‘kknn’, ‘mco’, ‘party’, ‘randomForest’, ‘reshape2’, ‘covr’

# %%
install.packages("lightgbm")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# After running the installation cells above, run the cell below to load the required libraries. If any packages still fail to load, you may need to investigate their specific installation requirements.

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")
require("primes")
require("utils")
require("rlist")
require("yaml")
require("lightgbm")
require("DiceKriging")
require("mlrMBO")

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"     "num_leaves"        "min_data_in_leaf"
#  [4] "feature_fraction"  "bagging_fraction"  "bagging_freq"
#  [7] "max_depth"         "lambda_l1"         "lambda_l2"
# [10] "min_child_samples" "min_gain_to_split" "y"
# [13] "dob"               "eol"               "error.message"
# [16] "exec.time"         "ei"                "error.model"
# [19] "train.time"        "prop.type"         "propose.time"
# [22] "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction bagging_fraction
#            <num>      <int>            <int>            <num>            <num>
# 1:    0.01009514         38               23        0.5129452        0.6409958
#    bagging_freq max_depth lambda_l1 lambda_l2 min_child_samples
#           <int>     <int>     <num>     <num>             <int>
# 1:            6         8  3.510165 0.6105619                95
#    min_gain_to_split
#                <num>
# 1:         0.6936558
# [1] 0.9312319

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 556088
#
# $max_depth
# [1] 8
#
# $min_gain_to_split
# [1] 0.6936558
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 3.510165
#
# $lambda_l2
# [1] 0.6105619
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.6409958
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01009514
#
# $feature_fraction
# [1] 0.5129452
#
# $num_leaves
# [1] 38
#
# $min_data_in_leaf
# [1] 23
#
# $bagging_freq
# [1] 6
#
# $min_child_samples
# [1] 95

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Warning message in dir.create("kaggle"):
# “'kaggle' already exists”
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 02:29:42 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
